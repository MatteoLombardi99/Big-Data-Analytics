# %% [markdown]
# Progetto Data Analytics - attività 2

# %% [markdown]
# Il progetto si suddivide nelle seguenti parti:
#
# * Introduzione e descrizione generale del Dataset
# * Esplorazione del dataset
# * Analisi della stazionarietà
# * Previsione delle temperature medie mensili del Bangladesh degli ultimi due anni del periodo 2000-2011
# * Conclusione

# %% [markdown]
# # **Introduzione**

# %% [markdown]
# Il dataset utilizzato per l'analisi è Weather Timeseries Data in Bangladesh, disponibile su kaggle al link https://www.kaggle.com/datasets/farukalam/weather-timeseries-data-in-sylhet-bangladesh.
#
# Il dataset presenta 12113 righe e 7 colonne. Ogni riga contiene il numero del giorno (da 1 a 365 o 366) e l'anno in cui sono state effettuate delle misurazioni sulle condizioni metereologiche in Bangladesh. Le colonne contengono dati giornalieri medi sulla velocità del vento, l'umidità specifica, l'umidità relativa, le precipitazioni e la temperatura.
#
# In particolare, ho deciso di concentrarmi sulle temperature medie giornaliere del periodo 2000-2011.

# %% [markdown]
# Carico il dataset presente su Google Drive.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

#import os
#os.chdir('/content/drive/MyDrive/Big_Data_Analytics/Progetto_Data_Analytics')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

def adf_test(series):
    """Using an ADF test to determine if a series is stationary"""
    test_results = adfuller(series)
    print('ADF Statistic: ', test_results[0])
    print('P-Value: ', test_results[1])
    print('Critical Values:')
    for thres, adf_stat in test_results[4].items():
        print('\t%s: %.2f' % (thres, adf_stat))

ddf = pd.read_csv('weather_data.csv',encoding='latin-1')
df = df[['Year', 'Day', 'Temperature']]
df
# Out:
#        Year  Day  Temperature
# 0      1990    1        16.33
# 1      1990    2        15.68
# 2      1990    3        16.56
# 3      1990    4        17.09
# 4      1990    5        17.26
# ...     ...  ...          ...
# 12108  2023   56        24.52
# 12109  2023   57        24.62
# 12110  2023   58        24.28
# 12111  2023   59        23.97
# 12112  2023   60        24.52
#
# [12113 rows x 3 columns]

# %% [markdown]
# Nel dataset sono presenti due colonne, una relativa all'anno e l'altra al giorno in cui è stata calcolata la temperatura media. Abbiamo deciso di creare un'unica colonna contenente giorno, mese e anno.

# %%
def create_date(row):
  return pd.to_datetime(f"{int(row['Year'])}-01-01") + pd.Timedelta(days=row['Day']-1)

df['Date'] = df.apply(create_date, axis=1)
df = df[(df['Date']>='2000-01-01')&(df['Date']<='2011-12-31')]
df.drop(['Year', 'Day'], axis=1, inplace=True)
df = df.reset_index(drop=True)
df
# Out:
# <ipython-input-3-296a7071faaf>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Year', 'Day'], axis=1, inplace=True)
#       Temperature       Date
# 0           17.19 2000-01-01
# 1           16.74 2000-01-02
# 2           16.58 2000-01-03
# 3           16.76 2000-01-04
# 4           16.94 2000-01-05
# ...           ...        ...
# 4378        19.62 2011-12-27
# 4379        19.91 2011-12-28
# 4380        20.17 2011-12-29
# 4381        19.44 2011-12-30
# 4382        18.77 2011-12-31
#
# [4383 rows x 2 columns]

# %% [markdown]
# # **Esplorazione del dataset**

# %% [markdown]
# Visualizziamo la serie temporale nell'arco di tempo selezionato.

# %%
df.plot(x='Date',y='Temperature',figsize=(20,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# La serie risulta avere una stagionalità annuale e una struttura additiva.

# %% [markdown]
# Verifichiamo la presenza di eventuali NaN.

# %%
df.isna().sum()
# Out:
# Temperature    0
# Date           0
# dtype: int64

# %% [markdown]
# Andiamo a visualizzare il trend della serie.

# %%
df0=df.copy()
df0.set_index('Date',inplace=True)
df0['Temperature'].plot()
df0['Temperature'].rolling(365,center=True).mean().plot(figsize=(20,5))
plt.tight_layout()
plt.show()

# %% [markdown]
# Come è possibile vedere dal grafico, il trend risulta essere costante.

# %% [markdown]
# # **Analisi della stazionarietà**

# %% [markdown]
# Per rendere stazionaria la serie temporale è necessario rimuovere la stagionalità, il trend e il rumore. D'altronde, nel nostro caso, il trend non va rimosso in quanto costante e il rumore non va regolarizzato in quanto additivo.
#
# Per rimuovere la stagionalità, invece, effetuiamo un subsampling della serie: per ogni mese consideriamo la temperatura media in modo tale da avere 144 misurazioni (12 per ciascuno dei 12 anni considerati).
#
# In particolare, per fare il campionamento tramite la funzione 'resample', indicizziamo la serie con le date delle misurazioni.

# %%
df.set_index('Date', inplace=True)
df_monthly_mean = df.resample('M').mean()
df_monthly_mean
# Out:
#             Temperature
# Date
# 2000-01-31    17.497419
# 2000-02-29    18.894828
# 2000-03-31    24.150645
# 2000-04-30    28.576333
# 2000-05-31    28.093226
# ...                 ...
# 2011-08-31    27.887097
# 2011-09-30    27.776667
# 2011-10-31    26.401613
# 2011-11-30    21.522000
# 2011-12-31    18.687097
#
# [144 rows x 1 columns]

# %% [markdown]
# Plottiamo la nuova serie temporale con anche il trend.

# %%
plt.figure(figsize=(20, 5))

plt.plot(df_monthly_mean.index, df_monthly_mean['Temperature'], color='c', marker='o', markerfacecolor='b', linestyle='-')

df0=df_monthly_mean.copy()

plt.plot(df0.index, df0['Temperature'])
plt.plot(df0.index, df0['Temperature'].rolling(12, center=True).mean())

plt.xlabel('Data')
plt.ylabel('Temperatura')
plt.grid(True)

plt.tight_layout()

plt.show()

# %% [markdown]
# Proseguiamo con la rimozione della stagionalità dalla serie temporale sotto-campionata tramite Lag-12 Differencing,
#
# In più, effettuiamo l'Augmented Dickey Fuller Test (ADF) per verificare che effettivamente la serie destagionalizzata sia stazionaria.

# %%
df_monthly_mean['diff12_Temperature']=df_monthly_mean['Temperature'].diff(12)
plt.plot(df_monthly_mean['diff12_Temperature'])
plt.show()

print()
adf_test(df_monthly_mean['diff12_Temperature'].dropna())
# Out:
# ADF Statistic:  -4.2766226492528245
# P-Value:  0.00048749201388223327
# Critical Values:
# 	1%: -3.49
# 	5%: -2.89
# 	10%: -2.58

# %% [markdown]
# Il valore ADF Statistic ottenuto risulta essere più piccolo dei valori critici. Dunque, poiché il test è significativo essendo il p-value più piccolo di 0.05, possiamo concludere che la serie è stazionaria.

# %% [markdown]
# Per identificare e visualizzare la presenza di autocorrelazione nella serie temporale utilizziamo il correlogramma Autocorrelation Function, strumento grafico utilizzato per anallizzare la correlazione tra la serie temporale e i suoi lag.
#
# Se i valori di autocorrelazione cadono al di fuori della zona colorata, allora vi è una correlazione significativa a quei lag specifici.

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(df_monthly_mean['Temperature'].dropna(),lags=48)
plt.ylabel('Correlazione Temperatura')
plt.xlabel('Lags')
plt.title('Autocorrelazione della serie')
plt.show()

plot_acf(df_monthly_mean['diff12_Temperature'].dropna(),lags=48)
plt.ylabel('Correlazione Temperatura')
plt.xlabel('Lags')
plt.title('Autocorrelazione della serie destagionalizzata')
plt.show()

# %% [markdown]
# Il primo grafico, ovvero il correlogramma della serie originale, mette in evidenza la stagionalità annuale della serie e presenta elevati valori di autocorrelazione. Invece, nel secondo grafico sono presenti valori inferiori di autocorrelazione, rispetto al primo, e non è più presente alcuna stagionalità.

# %% [markdown]
# Eseguiamo adesso il test di Ljung-Box per verificare la presenza di valori di autocorrelazione significativi.

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

print('Ljung-Box serie originale')
print(acorr_ljungbox(df_monthly_mean['Temperature'], return_df=True))
print()

print('Ljung-Box serie destagionalizzata')
print(acorr_ljungbox(df_monthly_mean['diff12_Temperature'].dropna(), return_df=True))
# Out:
# Ljung-Box serie originale
#        lb_stat     lb_pvalue
# 1    89.052783  3.844176e-21
# 2   104.528538  2.004086e-23
# 3   107.493148  3.799927e-23
# 4   139.542793  3.536105e-29
# 5   198.999234  4.650418e-41
# 6   268.253172  5.129077e-55
# 7   328.600871  4.670530e-67
# 8   360.910719  4.240636e-73
# 9   363.162236  9.768569e-73
# 10  381.445213  8.332548e-76
#
# Ljung-Box serie destagionalizzata
#       lb_stat  lb_pvalue
# 1    1.967126   0.160753
# 2    5.226698   0.073289
# 3    6.857692   0.076575
# 4    7.206155   0.125387
# 5    7.745564   0.170827
# 6    7.789481   0.253936
# 7    9.051820   0.248957
# 8   11.110815   0.195499
# 9   12.395992   0.191894
# 10  12.975514   0.225044

# %% [markdown]
# Nel test di Ljung-Box, l'ipotesi nulla consiste nel supporre che la serie temporale non presenta autocorrelazione fino al lag specificato.
#
# Per la serie originale si ottengono valori di p-value molto piccoli, dunque si può rifiutare l'ipotesi nulla. Questo permette di dire che sono presenti autocorrelazioni significative nella serie temporale e, in effetti, lb_stat cresce all'aumentare del numero di lag, il che suggerisce la presenza di un pattern stagionale.
#
# Invece, per la serie destagionalizzata si ottengono valori di p-value maggiori di 0.05. Questo vuol dire che non si può rifiutare l'ipotesi nulla e che quindi non c'è un'autocorrelazione significativa nella serie temporale. Questo è coerente col fatto che abbiamo destagionalizzato la serie e, dunque, la serie non presenta più una forte dipendenza tra i suoi valori passati e futuri.

# %% [markdown]
# # **Previsione**

# %% [markdown]
# Applichiamo un modello autoregressivo (AR) per prevedere le temperature medie mensili degli ultimi due anni, basandoci sulle temperature degli anni precedenti.

# %% [markdown]
# Innanzitutto, rimuoviamo il trend ma non la stagionalità.
#
# Consideriamo il Partial Autocorrelation Function (PACF) della serie privata soltanto del trend che ci permette di determinare i lag significativi che possono poi essere utilizzati nel modello autoregressivo.

# %%
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.graphics.tsaplots import plot_pacf

#df_monthly_mean['diff1_Temperature']=df_monthly_mean['Temperature'].diff(1)
df_monthly_mean['diff1_Temperature']=df_monthly_mean['Temperature']

plot_pacf(df_monthly_mean['diff1_Temperature'].dropna(),lags=48)
plt.ylabel('Autocorrelazione parziale')
plt.xlabel('Lags')
plt.title('Autocorrelazione parziale: stazionaria con stagionalità additiva')
plt.show()

# %% [markdown]
# In particolare, è possibile notare che soltanto i primi lag risultano essere significativi, il che indica che la serie temporale può essere modellata in modo efficace con un modello AR.

# %% [markdown]
# Procediamo a dividere il dataset in training set e test set. Il primo contiene le misurazioni mensili dei primi dieci anni, mentre il secondo quelle degli ultimi due.

# %%
train = df_monthly_mean.iloc[:-24]
test = df_monthly_mean.iloc[-24:]

selector = ar_select_order(train['diff1_Temperature'].dropna(), 9, seasonal=True, period=12)
model = AutoReg(train['diff1_Temperature'].dropna(), lags=selector.ar_lags, seasonal=True, period=12).fit()

# %%
#transformed_forecasts = list(model.forecast(steps=len(test)))
#forecasts = []
#for idx in range(len(test)):
#    if idx == 0:
#        forecast = transformed_forecasts[idx] + train['Temperature'].iloc[-1]
#    else:
#        forecast = transformed_forecasts[idx] + forecasts[idx-1]
#
#    forecasts.append(forecast)

#test['forecasts']=forecasts
test['forecasts'] = list(model.forecast(steps=len(test)))


df_monthly_mean['Temperature'].plot(color='k')
test['forecasts'].plot(color='red')
plt.show()
# Out:
# <ipython-input-14-09157b6ffe64>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['forecasts'] = list(model.forecast(steps=len(test)))

# %%
from sklearn.metrics import mean_absolute_error

MAE = mean_absolute_error(test['Temperature'], test['forecasts'])
print(f"L'errore assoluto medio (MAE) dell'autoregressione è {MAE}.")

mean_actual = np.mean(test['Temperature'])

relative_mae = MAE / mean_actual

print(f"L'errore assoluto medio relativo dell'autoregressione è {round(relative_mae*100,2)}%")
# Out:
# L'errore assoluto medio (MAE) dell'autoregressione è 0.40569064679449457.
# L'errore assoluto medio relativo dell'autoregressione è 1.63%

# %% [markdown]
# # **Conclusione**

# %% [markdown]
# Tramite l'analisi della serie temporale relativa alle temperature medie del Bangladesh negli anni 2000-2011 e la trasformazione in serie stazionaria, è stato possibile costruire un modello autoregressivo per predire con successo (con una percentuale di errore di solo l'1.66%) le misurazioni degli ultimi due anni.
